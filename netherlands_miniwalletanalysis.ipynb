# %% [markdown]
# # SECRID  DATA ANALYSIS PROJECT
#
#
# <span style="color: gray; font-size:1em;">September-2019</span>
#
#
# ## Table of Contents
# * [Introduction](#introduction)
# * [Section One - Import Data into IDE](#import_data)
#     * [Part I - Gathering Data](#gather_data)
#     * [Part II - Assessing Data](#assess_data)
#     * [Part III - Cleaning Data](#clean_data)

# %% [markdown]
# <a id='introduction'></a>
# ## Introduction
#
# SECRID is a business entity based in the Netherlands. It produces, stocks and sells designer wallets, particularly leather based wallets in more than 100 countries all over the world.
#
# This notebook explores SECRID miniwallet sales data

# %% [markdown]
# <a id='#import_data'></a>
# ## Section One : Import Data into IDE

# %% [markdown]
# <a id='gather_data'></a>
# ## Part I : Gathering Data

# %%
# load required libraries
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import read_excel

import zipfile
import xlsxwriter

import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.ticker as ticker
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
plt.style.use('seaborn')

import six

from datetime import datetime, timedelta

# environment settings:
pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_column',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_seq_items',None)
pd.set_option('display.max_colwidth', 500)
pd.set_option('expand_frame_repr', True)

# %% [markdown]
# ### Load .xlxs files

# %%
#load sales 2015 
df1 = pd.read_excel('SECRID DATA.xlsx',0) #load first spreadsheet of SECRID DATA.xlxs

# %%
# #load sales 2016 
df2 = pd.read_excel('SECRID DATA.xlsx',1) #load second spreadsheet of SECRID DATA.xlxs

# %%
#load sales 2017
df3 = pd.read_excel('SECRID DATA.xlsx',2)  #load third spreadsheet ofSECRID DATA.xlxs

# %%
#load sales 2018
df4 = pd.read_excel('SECRID DATA.xlsx',3)  #load fourth spreadsheet of SECRID DATA.xlxs

# %%
#load sales 2019
df5 = pd.read_excel('SECRID DATA.xlsx',4)  #load fifth spreadsheet of SECRID DATA.xlxs

# %%
# load product data
df6 = pd.read_excel('SECRID DATA.xlsx',5) #load sixth spreadsheet of SECRID DATA.xlxs

# %%
#combine df4 and df5  into one complete dataframe 'df' for miniwallet data
df = pd.concat([df4, df5])

# %% [markdown]
# <a id='assess_data'></a>
# ## Part II - Assessing  Data

# %%
df.head() #preview first five rows

# %%
df.tail() #preview last five rows

# %%
# Check size of the dataframe 
df.shape

# %%
# list names of columns in dataframe
df.columns

# %%
# View info of the dataframe 
df.info()

# %%
# view some of the core statistics about columns
df.describe(include='all')

# %%
# check the Data types (dtypes) of each column in Dataframe
df.dtypes

# %%
# Total sum of duplicate rows
df.duplicated().sum() # returns a Boolean Series with True value for each duplicated row and sums them

# %%
#return the number of unique elements in each column
print(df.nunique())

# %%
df.count() #returns the number of non-missing values for each column or row

# %%
#Total missing values(NaN) in a DataFrame
df.isnull().sum().sum()

# %%
#Count number of NaN for each column in DataFrame
print(df.isnull().sum())

# %% [markdown]
# <a id='issues'></a>
# **Quality issues**
#  * Rename column names to have clear, descriptive names in small letters according to best practice. Column 'name' can be renamed to 'customer_name' and column 'material' can be renamed to 'type_of_material'
#  * Set to columns to appropriate category data type: 'internal_id', 'document_number', 'customer_name', 'customer _category', 'retailer_role', 'shipping_country', 'item', 'display_name', 'pim_category','type_of_material',
#    'pim_colour', 'wsl', 'while_stock_lasts' and 'cardprotector_colour'

# %% [markdown]
# <a id='clean_data'></a>
# ## Part III - Cleaning Data

# %%
# Create copy of original DataFrame
df_clean = df.copy()

# %%
#Fixing messy column names
df_clean.columns = df_clean.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
# change column names using rename function
df_clean.rename(columns={                                                 
                         'name':'customer_name',
                         'wsl_+':'wsl',
                         'material':'type_of_material' }, 
                 inplace=True)

# %% [markdown]
# **Test**

# %%
df_clean.columns #List of column names in df_clean Dataframe

# %% [markdown]
# **Define**
# <br>Set appropriate data types for fields mentioned in the [Quality issues](#issues)

# %%
# use .astype to change data type of dataframe columns
df_clean = df_clean.astype({"internal_id":'category',"document_number":'category', "customer_name":'category', "customer_category":'category', "retailer_role":'category', "shipping_country":'category', "item":'category',"display_name":'category', "pim_category":'category', "type_of_material":'category', "pim_colour":'category',"wsl":'category', "while_stock_lasts":'category', "cardprotector_colour":'category'})

# %% [markdown]
# **Test**

# %%
df_clean.info()

# %%
# view some of the core statistics about columns
df_clean.describe(include='all')

# %% [markdown]
# ### content structure of sales dataset
# The sales data contains 18 columns (variables) and 1,609,533 rows (entries).
# This is evidence that 1,609,533 sale transactions were completed in the January 2015 – July 2019 period for SECRID business. The dataset contained features about:
#
# * Products for sale: item, display_name, pim_category, pim_colour, type_of_material and cardprotector_colour
# * The country the item was shipped to : shipping_country
# * Customer data:  customer_name, customer_category and retailer_role
# * Sale transactions: internal_id, document_number, quantity, amount, amount(foreign_currency) and date
#
#
# ### Detected Missing Values
# A null value is a value in a field that appears to be blank. A null value is a field with no value.
# The table below indicates the number and  the resulting percentage of missing values per column.
#
# | Variable Name  | Value Count| Number Of Missing Values| % Of Missing Values
# | -------------  | ------------- |------------- |-------------
# | internal_id    | 1,609,533  |0 |0%
# | document_number| 1,609,533  |0 |0%
# | date            | 1,609,533  |0 |0%
# | customer_name  | 1,609,533  |0 |0%
# | customer_category  | 1,604,118  |5,415     |0.34%
# | retailer_role      | 45,994     |1,563,539 |97.14%
# | shipping_country   | 1,603,431  |6,102     |0.38%
# | item               | 1,609,533  |0 |0%
# | display_name       | 1,609,533  |0 |0%
# | quantity           | 1,609,533  |0 |0%
# | amount             | 1,609,533  |0 |0%
# | amount(foreign_currency)| 1,609,533 |0     |0%
# | type_of_material        | 1,608,493 |1,040 |0.065%
# | pim_category            | 1,608,493 |1,040 |0.065%
# | pim_colour              | 1,603,475 |6,058 |0.38%
# | wsl_+                   | 1,609,533 |0     |0%
# | while_stock_lasts       | 1,609,533 |0     |0%
# | cardprotector_colour    | 1,556,521 |53,012|3.29%

# %% [markdown]
# ## MINIWALLET ANALYSIS

# %%
# filter to only category of interest ('Miniwallet')
miniwalletdf =df_clean[(df_clean.pim_category == 'Miniwallet')]

# %%
# rows with positive values in Quantity column and Amount column
miniwalletdf= miniwalletdf[(miniwalletdf.amount>0) & (miniwalletdf.quantity>0)]

# %%
miniwalletdf.head() #preview first five rows
# Out:
#    internal_id document_number       date  \
# 9      1393213       I-1729849 2018-01-02
# 10     1393213       I-1729849 2018-01-02
# 11     1393213       I-1729849 2018-01-02
# 12     1393213       I-1729849 2018-01-02
# 13     1393213       I-1729849 2018-01-02
#
#                               customer_name customer_category retailer_role  \
# 9   C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 10  C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 11  C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 12  C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 13  C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
#
#    shipping_country            item               display_name  quantity  \
# 9       Netherlands  MM-Pink Silver      Miniwallet Matte Pink         2
# 10      Netherlands       MC-Orange  Miniwallet Crisple Orange         2
# 11      Netherlands        MC-Black   Miniwallet Crisple Black         2
# 12      Netherlands  MM-Blue Silver      Miniwallet Matte Blue         1
# 13      Netherlands        MV-Black   Miniwallet Vintage Black         6
#
#     amount  amount_foreign_currency pim_category type_of_material pim_colour  \
# 9    45.80                    45.80   Miniwallet            Matte       Pink
# 10   50.38                    50.38   Miniwallet          Crisple     Orange
# 11   50.38                    50.38   Miniwallet          Crisple      Black
# 12   22.90                    22.90   Miniwallet            Matte       Blue
# 13  137.40                   137.40   Miniwallet          Vintage      Black
#
#    wsl while_stock_lasts cardprotector_colour
# 9   No               Yes               Silver
# 10  No                No               Silver
# 11  No                No                Black
# 12  No               Yes               Silver
# 13  No                No                Black

# %%
miniwalletdf.type_of_material.describe() #overview of variable; count, unique, top,freq

# %%
#Types of leather used in production of miniwallet
print (miniwalletdf.type_of_material.cat.categories) # Get list of categories in categorical variable

# %%
miniwalletdf.display_name.value_counts() #transactions per display name

# %%
print(miniwalletdf.isnull().sum()) # check for mising values in miniwalletdf

# %% [markdown]
# ## Filtering to desired datasets

# %% [markdown]
# ## TIMELESS DATAFRAME

# %%
timeless_list = ["Original","Vintage","Dutch Martin","Vegetable Tanned"]

# %%
timelessdisplay = miniwalletdf[ miniwalletdf.type_of_material.isin(timeless_list)]

# %%
timelessdisplay.display_name.value_counts() # missing Miniwallet Vegan Soft Touch Black
                                            # includes Slimallet Perforated Cognac and Slimwallet Perforated Black

# %%
#Miniwallet Vegan Soft Touch Black subset dataframe
vegansoft_black = miniwalletdf[miniwalletdf.display_name.str.contains("Miniwallet Vegan Soft Touch Black")]

# %%
vegansoft_black.head()

# %%
# combine two dataframes
miniwallettimelessdesign = pd.concat([timelessdisplay,vegansoft_black])

# %%
# delete all rows with display_name 'Slimallet Perforated Cognac and Slimwallet Perforated Black'
miniwallettimelessdesign = miniwallettimelessdesign[~miniwallettimelessdesign.display_name.str.contains("Slimwallet")]

# %%
#insert new column with one value 'tm'
miniwallettimelessdesign['design']='tm'

# %%
miniwallettimelessdesign.tail()

# %%
timelessdesign= miniwallettimelessdesign.groupby(
   ['display_name']
).agg(
    {
         'amount':sum,    # Sum revenue per customer
         'quantity': sum  # get the sum of items sold per year
         
    }
)

timelessdesign.sort_values(by=['amount'], inplace=True, ascending=False)

# %%
timelessdesign

# %%
#export to csv
miniwallettimelessdesign.to_csv('timelessdesign.csv', index = None, header=True)

# %%
sum(amount for amount in miniwallettimelessdesign.amount if amount>0)

# %% [markdown]
# ## FASHIONABLE DATAFRAME

# %%
fashionable_list = ["Crisple","Cleo","Prism","Nile","Vegetable Tanned Stitched","Ornament","Metallic","Indigo"]

# %%
fashinabledisplay = miniwalletdf[ miniwalletdf.type_of_material.isin(fashionable_list)]

# %%
fashinabledisplay.head()

# %%
fashinabledisplay.display_name.value_counts()

# %%
matte = miniwalletdf[(miniwalletdf.display_name == 'Miniwallet Matte Black & Yellow') | (miniwalletdf.display_name == 'Miniwallet Matte Purple') | (miniwalletdf.display_name == 'Miniwallet Matte Black & Red')]

# %%
matte.display_name.value_counts()

# %%
rango = miniwalletdf[(miniwalletdf.display_name == 'Miniwallet Rango Green') | (miniwalletdf.display_name == 'Miniwallet Rango Red-Bordeaux') | (miniwalletdf.display_name == 'Miniwallet Rango Violet-Violet')]

# %%
rango.display_name.value_counts()

# %%
diamond = miniwalletdf[(miniwalletdf.display_name == 'Miniwallet Diamond Black')]

# %%
diamond.display_name.value_counts()

# %%
optical = miniwalletdf[(miniwalletdf.display_name == 'Miniwallet Optical Black')]

# %%
optical.display_name.value_counts()

# %%
cubic = miniwalletdf[(miniwalletdf.display_name == 'Miniwallet Cubic Black-Blue')]

# %%
cubic.display_name.value_counts()

# %%
dash = miniwalletdf[(miniwalletdf.display_name == 'Miniwallet Dash Navy')]

# %%
dash.display_name.value_counts()

# %%
miniwalletfashionabledesign = pd.concat([fashinabledisplay,matte,rango,diamond,optical,cubic,dash])

# %%
#insert new column with one value 'fsh'
miniwalletfashionabledesign['design']='fsh'

# %%
miniwalletfashionabledesign.head()

# %%
miniwalletfashionabledesign.display_name.value_counts()

# %%
sum(amount for amount in miniwalletfashionabledesign.amount)

# %%
fashionabledesign= miniwalletfashionabledesign.groupby(
   ['display_name']
).agg(
    {
         'amount':sum,    # Sum revenue per customer
         'quantity': sum  # get the sum of items sold per year
         
    }
)

fashionabledesign.sort_values(by=['amount'], inplace=True, ascending=False)

# %%
fashionabledesign
# Out:
#                                                              amount  quantity
# display_name
# Miniwallet Crisple Black                                 1243067.22     48948
# Miniwallet Indigo 5                                       803593.23     28150
# Miniwallet Cubic Black-Blue                               800526.43     32066
# Miniwallet Prism Black-Red                                704370.77     28216
# Miniwallet Crisple Black-Gold                             537880.95     21449
# Miniwallet Metallic Champagne-Brown                       453294.45     17785
# C-Streetview                                                   0.00         0
# Cardprotector Black                                            0.00         0
# Cardprotector Blue                                             0.00         0
# Cardprotector Bordeaux                                         0.00         0
# Cardprotector Brown                                            0.00         0
# Cardprotector Brushed Black                                    0.00         0
# Cardprotector Brushed Silver                                   0.00         0
# Cardprotector Diamond Black Exclusive                          0.00         0
# Cardprotector Gold                                             0.00         0
# Cardprotector Green                                            0.00         0
# Cardprotector KLM Gold Exclusive                               0.00         0
# Cardprotector KLM Red Exclusive                                0.00         0
# Cardprotector Laser Logo Black                                 0.00         0
# Cardprotector Laser Logo Blue                                  0.00         0
# Cardprotector Laser Logo Brushed Black                         0.00         0
# Cardprotector Laser Logo Brushed Silver                        0.00         0
# Cardprotector Laser Logo Green                                 0.00         0
# Cardprotector Laser Magnolia Black                             0.00         0
# Cardprotector Laser Magnolia Bordeaux                          0.00         0
# Cardprotector Laser Provence Green                             0.00         0
# Cardprotector Laser Provence Violet                            0.00         0
# Miniwallet Dutch Martin Cacao-Brown                            0.00         0
# Miniwallet Dutch Martin Olive                                  0.00         0
# Miniwallet limited white-black                                 0.00         0
# Miniwallet Polished Black (KLM)                                0.00         0
# Miniwallet Rango Black                                         0.00         0
# Miniwallet Rango Blue-Titanium                                 0.00         0
# Miniwallet Rango Brown-Brown                                   0.00         0
# Miniwallet Rango Green-Gold                                    0.00         0
# Miniwallet Recycled Natural                                    0.00         0
# Miniwallet Recycled Stone                                      0.00         0
# Additional Slide Blue                                          0.00         0
# Miniwallet Veg Black                                           0.00         0
# Miniwallet Veg Caramello                                       0.00         0
# Miniwallet Veg Espresso                                        0.00         0
# Miniwallet Veg Navy                                            0.00         0
# Miniwallet Veg Rosso                                           0.00         0
# Miniwallet Vegan Soft Touch Black                              0.00         0
# Miniwallet Vintage Black                                       0.00         0
# Miniwallet Vintage Blue                                        0.00         0
# Miniwallet Vintage Brown                                       0.00         0
# Miniwallet Vintage Chocolate                                   0.00         0
# Miniwallet Vintage Cognac                                      0.00         0
# Miniwallet Vintage Cognac-Rust                                 0.00         0
# Miniwallet Vintage Concrete                                    0.00         0
# Miniwallet Vintage Grey                                        0.00         0
# Miniwallet Vintage Grey-Black                                  0.00         0
# Miniwallet Vintage Ochre                                       0.00         0
# Miniwallet Vintage Olive-Black                                 0.00         0
# Miniwallet Vintage Rose                                        0.00         0
# Miniwallet Polished Navy Exclusive                             0.00         0
# Miniwallet Perforated Cognac                                   0.00         0
# Miniwallet Dutch Martin Whiskey                                0.00         0
# Miniwallet Perforated Black                                    0.00         0
# Miniwallet Glamour Bronze                                      0.00         0
# Miniwallet Glamour Green                                       0.00         0
# Miniwallet Matte Black                                         0.00         0
# Miniwallet Matte Blue                                          0.00         0
# Miniwallet Matte Brick-Black                                   0.00         0
# Miniwallet Matte Chalk                                         0.00         0
# Miniwallet Matte Green                                         0.00         0
# Miniwallet Matte Green-Black                                   0.00         0
# Miniwallet Matte Grey-Black                                    0.00         0
# Miniwallet Matte Lilac-Black                                   0.00         0
# Miniwallet Matte Nightblue                                     0.00         0
# Miniwallet Matte Petrol                                        0.00         0
# Miniwallet Matte Pink                                          0.00         0
# Miniwallet Original Black                                      0.00         0
# Miniwallet Original Black Exclusive                            0.00         0
# Miniwallet Original Black Red Exclusive                        0.00         0
# Miniwallet Original Bordeaux                                   0.00         0
# Miniwallet Original Cognac-Brown                               0.00         0
# Miniwallet Original Dark Brown                                 0.00         0
# Miniwallet Original Emerald                                    0.00         0
# Miniwallet Original Fuchsia                                    0.00         0
# Miniwallet Original Green                                      0.00         0
# Miniwallet Original Navy                                       0.00         0
# Miniwallet Original Navy-Blue                                  0.00         0
# Miniwallet Original Red-Red                                    0.00         0
# Twinwallet Vintage Ochre                                       0.00         0

# %% [markdown]
# ## COMBINED TIMELESS AND FASHIONABLE DESIGN DATAFRAMES

# %%
miniwalletdesign =  pd.concat([miniwallettimelessdesign, miniwalletfashionabledesign])

# %%
miniwalletdesign.head()
# Out:
#    internal_id document_number       date  \
# 13     1393213       I-1729849 2018-01-02
# 14     1393213       I-1729849 2018-01-02
# 18     1393213       I-1729849 2018-01-02
# 27     1393338        I-180001 2018-01-02
# 28     1393338        I-180001 2018-01-02
#
#                                         customer_name customer_category  \
# 13            C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery
# 14            C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery
# 18            C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery
# 27  C-14929 Stop Sac Diffusion SARL / La Maroquinerie     Leather goods
# 28  C-14929 Stop Sac Diffusion SARL / La Maroquinerie     Leather goods
#
#    retailer_role shipping_country          item  \
# 13           NaN      Netherlands      MV-Black
# 14           NaN      Netherlands      MV-Brown
# 18           NaN      Netherlands  MDM-Bordeaux
# 27           NaN           France       M-Black
# 28           NaN           France     M-Red-Red
#
#                         display_name  quantity  amount  \
# 13          Miniwallet Vintage Black         6  137.40
# 14          Miniwallet Vintage Brown         6  137.40
# 18  Miniwallet Dutch Martin Bordeaux         2   56.38
# 27         Miniwallet Original Black         4   91.60
# 28       Miniwallet Original Red-Red         3   68.70
#
#     amount_foreign_currency pim_category type_of_material pim_colour wsl  \
# 13                   137.40   Miniwallet          Vintage      Black  No
# 14                   137.40   Miniwallet          Vintage      Brown  No
# 18                    56.38   Miniwallet     Dutch Martin   Bordeaux  No
# 27                    91.60   Miniwallet         Original      Black  No
# 28                    68.70   Miniwallet         Original        Red  No
#
#    while_stock_lasts cardprotector_colour design
# 13                No                Black     tm
# 14                No               Silver     tm
# 18               Yes                Black     tm
# 27                No               Silver     tm
# 28                No                  Red     tm

# %%
miniwalletdesign.tail()
# Out:
#        internal_id document_number       date  \
# 310607     5095306       I-1929029 2019-07-31
# 310657     5095309       I-1929032 2019-07-31
# 310686     5095612       I-1929033 2019-07-31
# 310816     5095617       I-1929038 2019-07-31
# 310870     5095718       I-1929041 2019-07-31
#
#                                                    customer_name  \
# 310607  C-7657 Vicente Choya Almaraz-Maria Isabel Vazquez Varela
# 310657                           C-9633 Karl Rüter GmbH & Co. KG
# 310686                         C-5000 Richard Renner & Rehm GmbH
# 310816                                         C-9063 Traumstern
# 310870                  C-11000 Kaut-Bullinger Einzelhandel GmbH
#
#        customer_category retailer_role shipping_country      item  \
# 310607    Luggage/Travel           NaN            Spain  MDa-Navy
# 310657        Stationery         Style          Germany  MDa-Navy
# 310686        Stationery  Availability          Germany  MDa-Navy
# 310816      Design Store  Availability          Germany  MDa-Navy
# 310870        Stationery      Exposure          Germany  MDa-Navy
#
#                 display_name  quantity  amount  amount_foreign_currency  \
# 310607  Miniwallet Dash Navy         1   25.19                    25.19
# 310657  Miniwallet Dash Navy         2   50.38                    50.38
# 310686  Miniwallet Dash Navy         1   25.19                    25.19
# 310816  Miniwallet Dash Navy         2   50.38                    50.38
# 310870  Miniwallet Dash Navy         2   50.38                    50.38
#
#        pim_category type_of_material pim_colour wsl while_stock_lasts  \
# 310607   Miniwallet             Dash       Blue  No                No
# 310657   Miniwallet             Dash       Blue  No                No
# 310686   Miniwallet             Dash       Blue  No                No
# 310816   Miniwallet             Dash       Blue  No                No
# 310870   Miniwallet             Dash       Blue  No                No
#
#        cardprotector_colour design
# 310607                Black    fsh
# 310657                Black    fsh
# 310686                Black    fsh
# 310816                Black    fsh
# 310870                Black    fsh

# %%
sum(amount for amount in miniwalletdesign.amount)
# Out:
# 32654763.420032613

# %%
#export to csv
miniwalletdesign.to_csv('miniwalletdesign.csv', index = None, header=True)

# %%
rankrevenuedesign= miniwalletdesign.groupby(
   ['design']
).agg(
    {
         'amount':sum,    # Sum revenue per customer
         'quantity': sum  # get the sum of items sold per year
         
    }
)

rankrevenuedesign.sort_values(by=['amount'], inplace=True, ascending=False)

# %%
rankrevenuedesign
# Out:
#             amount  quantity
# design
# tm     22745962.09    968776
# fsh     9908801.33    377026

# %% [markdown]
# ### NETHERLANDS MINIWALLET ANALYSIS

# %%
#filter miniwalletdesign for items only sold in the netherlands.

# %%
# filter to only country of interest ('Miniwallet')
miniwalletdesign =miniwalletdesign[(miniwalletdesign.shipping_country == 'Netherlands')]

# %%
miniwalletdesign.shipping_country.value_counts()

# %%
netherlandsrankrevenuedesign= miniwalletdesign.groupby(
   ['design']
).agg(
    {
         'amount':sum,    # Sum revenue per customer
         'quantity': sum  # get the sum of items sold per year
         
    }
)

netherlandsrankrevenuedesign.sort_values(by=['amount'], inplace=True, ascending=False)

# %%
netherlandsrankrevenuedesign
# Out:
#            amount  quantity
# design
# tm     3931013.67    165177
# fsh    1551885.73     57662

# %%
# netherlands timeless breakdown
miniwallettimelessdesign = miniwallettimelessdesign[(miniwallettimelessdesign.shipping_country == 'Netherlands')]

# %%
miniwallettimelessdesign.head()
# Out:
#     internal_id document_number       date  \
# 13      1393213       I-1729849 2018-01-02
# 14      1393213       I-1729849 2018-01-02
# 18      1393213       I-1729849 2018-01-02
# 195     1394925        I-180013 2018-01-02
# 197     1394925        I-180013 2018-01-02
#
#                                customer_name customer_category retailer_role  \
# 13   C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 14   C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 18   C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 195            C-13603 Secrid Webshop België            Intern           NaN
# 197            C-13603 Secrid Webshop België            Intern           NaN
#
#     shipping_country            item                      display_name  \
# 13       Netherlands        MV-Black          Miniwallet Vintage Black
# 14       Netherlands        MV-Brown          Miniwallet Vintage Brown
# 18       Netherlands    MDM-Bordeaux  Miniwallet Dutch Martin Bordeaux
# 195      Netherlands         M-Black         Miniwallet Original Black
# 197      Netherlands  MV-Cognac-Rust    Miniwallet Vintage Cognac-Rust
#
#      quantity  amount  amount_foreign_currency pim_category type_of_material  \
# 13          6  137.40                   137.40   Miniwallet          Vintage
# 14          6  137.40                   137.40   Miniwallet          Vintage
# 18          2   56.38                    56.38   Miniwallet     Dutch Martin
# 195         1   41.28                    41.28   Miniwallet         Original
# 197         1   41.28                    41.28   Miniwallet          Vintage
#
#     pim_colour wsl while_stock_lasts cardprotector_colour design
# 13       Black  No                No                Black     tm
# 14       Brown  No                No               Silver     tm
# 18    Bordeaux  No               Yes                Black     tm
# 195      Black  No                No               Silver     tm
# 197      Brown  No                No                 Rust     tm

# %%
sum(amount for amount in miniwallettimelessdesign.amount)
# Out:
# 3931013.6699981624

# %%
netherlandstimelessdesign= miniwallettimelessdesign.groupby(
   ['display_name']
).agg(
    {
         'amount':sum,    # Sum revenue per customer
         'quantity': sum  # get the sum of items sold per year
         
    }
)

netherlandstimelessdesign.sort_values(by=['amount'], inplace=True, ascending=False)

# %%
netherlandstimelessdesign
# Out:
#                                                             amount  quantity
# display_name
# Miniwallet Vintage Black                                 635071.94     27374
# Miniwallet Vintage Brown                                 574871.75     24618
# Miniwallet Original Black                                539145.34     23334
# Miniwallet Vintage Chocolate                             385081.69     16431
# Miniwallet Vintage Cognac-Rust                           249268.71     10652
# Miniwallet Vintage Grey-Black                            178620.27      7647
# Miniwallet Vintage Olive-Black                           178504.52      7620
# Miniwallet Vintage Blue                                  174784.75      7486
# Miniwallet Original Red-Red                              146296.52      6294
# Miniwallet Original Dark Brown                           115832.14      4952
# Miniwallet Dutch Martin Whiskey                          113588.37      3925
# Miniwallet Original Navy-Blue                            111940.78      4734
# Miniwallet Original Cognac-Brown                          99585.80      4234
# Miniwallet Dutch Martin Nightblue                         69955.42      2434
# Miniwallet Original Bordeaux                              65453.93      2447
# Miniwallet Dutch Martin Cacao-Brown                       50885.49      1744
# Miniwallet Veg Espresso                                   44662.94      1552
# Miniwallet Vintage Rose                                   38922.82      1628
# Miniwallet Veg Caramello                                  33405.90      1161
# Miniwallet Original Green                                 25332.18      1088
# Miniwallet Perforated Black                               22212.52       862
# Miniwallet Perforated Cognac                              21038.50       800
# Miniwallet Veg Navy                                       15615.75       544
# Miniwallet Original Emerald                               13850.92       600
# Miniwallet Veg Rosso                                       8942.82       310
# Miniwallet Dutch Martin Bordeaux                           5788.71       203
# Miniwallet Original Fuchsia                                4334.37       181
# Miniwallet Vintage Concrete                                2750.91       110
# Miniwallet Vintage Ochre                                    916.00        40
# Miniwallet Vintage Cognac                                   825.19        34
# Miniwallet Dutch Martin Olive                               789.32        28
# Miniwallet Original Navy                                    714.54        30
# Miniwallet Vegan Soft Touch Black                           629.75        25
# Miniwallet Veg Black                                        620.18        22
# Miniwallet Vintage Grey                                     436.93        19
# Miniwallet Original Black Exclusive                         168.00         7
# Miniwallet Original Black Red Exclusive                     168.00         7
# Twinwallet Matte Blue                                         0.00         0
# Twinwallet Matte Blue Silver                                  0.00         0
# Twinwallet Matte Green                                        0.00         0
# Twinwallet Matte Purple                                       0.00         0
# Twinwallet Crisple Black                                      0.00         0
# Twinwallet Nile Black                                         0.00         0
# Twinwallet Nile Red                                           0.00         0
# Twinwallet Original Black                                     0.00         0
# Moneyband Red                                                 0.00         0
# Moneyband Pier                                                0.00         0
# Twinwallet Original Black Exclusive                           0.00         0
# Twinwallet Nile Brown                                         0.00         0
# Twinwallet Matte Black                                        0.00         0
# Moneyband No-Entry                                            0.00         0
# Moneyband Road Sign                                           0.00         0
# Moneyband Skyscraper                                          0.00         0
# Moneyband Starry Sky                                          0.00         0
# Moneyband Thames                                              0.00         0
# Moneyband Tire                                                0.00         0
# Moneyband Yellow Cab                                          0.00         0
# Moneyband Zebra                                               0.00         0
# Slimwallet Black Exclusive                                    0.00         0
# Slimwallet Black Red Exclusive                                0.00         0
# Slimwallet Crisple Black                                      0.00         0
# Slimwallet Crisple Black-Gold                                 0.00         0
# Twinwallet Original Cognac-Brown                              0.00         0
# Moneyband Light Stream                                        0.00         0
# Moneyband Neon Pink                                           0.00         0
# Twinwallet Original Fuchsia                                   0.00         0
# Twinwallet Vintage Cognac                                     0.00         0
# Twinwallet Vintage Chocolate                                  0.00         0
# Twinwallet Vintage Brown                                      0.00         0
# Twinwallet Vintage Black                                      0.00         0
# Twinwallet Veg Navy                                           0.00         0
# Twinwallet Recycled Stone                                     0.00         0
# Twinwallet Recycled Natural                                   0.00         0
# Twinwallet Perforated Cognac                                  0.00         0
# Twinwallet Perforated Black                                   0.00         0
# Twinwallet Original Red-Red                                   0.00         0
# Twinwallet Original Red Lipstick                              0.00         0
# Twinwallet Original Green                                     0.00         0
# Miniwallet limited white-black                                0.00         0
# Twinwallet Amazon Brown                                       0.00         0
# Money Band Pergola                                            0.00         0
# Moneyband Black                                               0.00         0
# Moneyband Blue                                                0.00         0
# Moneyband Brick                                               0.00         0
# Moneyband Cables                                              0.00         0
# Moneyband Central Park                                        0.00         0
# Moneyband Cobalt                                              0.00         0
# Moneyband Concrete                                            0.00         0
# Moneyband Construction                                        0.00         0
# Moneyband Groove                                              0.00         0
# Moneyband Harbour                                             0.00         0
# Moneyband Highway                                             0.00         0
# Miniwallet Stitch Magnolia Black                              0.00         0
# Miniwallet Stitch Magnolia Rosso                              0.00         0
# Cardslide Green                                               0.00         0
# Cardprotector Laser Zigzag Titanium                           0.00         0
# Cardprotector Lime                                            0.00         0
# Cardprotector Red                                             0.00         0
# Cardprotector Royal Orange                                    0.00         0
# Cardprotector Rust                                            0.00         0
# Cardprotector Silver                                          0.00         0
# Cardprotector Titanium Color                                  0.00         0
# Cardprotector Violet                                          0.00         0
# Cardprotector Wallflower                                      0.00         0
# Cardslide Black/Black                                         0.00         0
# Cardslide Blue                                                0.00         0
# Cardslide Constructure                                        0.00         0
# Cardslide Electrolime                                         0.00         0
# Cardslide KLM Black                                           0.00         0
# Miniwallet Stitch Magnolia Rose                               0.00         0
# Cardslide Monochrome                                          0.00         0
# Cardslide White                                               0.00         0
# Cardslide White/Bordeaux                                      0.00         0
# Lasersnijden - Spacer PMMA zwart - Dynamic Freitag REV01      0.00         0
# Lasersnijden - spacer PMMA zwart - Dynamic Freitag            0.00         0
# Miniwallet Amazon Brown                                       0.00         0
# Miniwallet Cleo Black                                         0.00         0
# Miniwallet Cleo Lavender                                      0.00         0
# Miniwallet Cleo Ochre                                         0.00         0
# Miniwallet Crisple Amber                                      0.00         0
# Miniwallet Crisple Black                                      0.00         0
# Miniwallet Crisple Black Exclusive                            0.00         0
# Miniwallet Crisple Black-Gold                                 0.00         0
# Cardprotector Laser Zigzag Black                              0.00         0
# Cardprotector Laser Tartan Rust                               0.00         0
# Cardprotector Laser Tartan Green                              0.00         0
# Cardprotector Laser Tartan Brown                              0.00         0
# Additional Slide Green                                        0.00         0
# Additional Slide White                                        0.00         0
# BQ Miniwallet Sample                                          0.00         0
# C-Facade                                                      0.00         0
# C-Streetview                                                  0.00         0
# Cardprotector Black                                           0.00         0
# Cardprotector Blue                                            0.00         0
# Cardprotector Bordeaux                                        0.00         0
# Cardprotector Brown                                           0.00         0
# Cardprotector Brushed Black                                   0.00         0
# Cardprotector Brushed Silver                                  0.00         0
# Cardprotector Diamond Black Exclusive                         0.00         0
# Cardprotector Gold                                            0.00         0
# Cardprotector Green                                           0.00         0
# Cardprotector KLM Gold Exclusive                              0.00         0
# Cardprotector KLM Red Exclusive                               0.00         0
# Cardprotector Laser Logo Black                                0.00         0
# Cardprotector Laser Logo Blue                                 0.00         0
# Cardprotector Laser Logo Brushed Black                        0.00         0
# Cardprotector Laser Logo Brushed Silver                       0.00         0
# Cardprotector Laser Logo Green                                0.00         0
# Cardprotector Laser Magnolia Black                            0.00         0
# Cardprotector Laser Magnolia Bordeaux                         0.00         0
# Cardprotector Laser Provence Green                            0.00         0
# Cardprotector Laser Provence Violet                           0.00         0
# Cardprotector Laser Structure Black                           0.00         0
# Cardprotector Laser Structure Titanium                        0.00         0
# Miniwallet Crisple Blue-Black                                 0.00         0
# Miniwallet Crisple Caramel                                    0.00         0
# Miniwallet Crisple Emerald                                    0.00         0
# Miniwallet Metallic Rose                                      0.00         0
# Miniwallet Nile Black                                         0.00         0
# Miniwallet Nile Brown                                         0.00         0
# Miniwallet Nile Red                                           0.00         0
# Miniwallet Nile Ruby                                          0.00         0
# Miniwallet Optical Black                                      0.00         0
# Miniwallet Ornament Black                                     0.00         0
# Miniwallet Ornament Rose                                      0.00         0
# Miniwallet Polished Black (KLM)                               0.00         0
# Miniwallet Polished Navy Exclusive                            0.00         0
# Miniwallet Prism Black                                        0.00         0
# Miniwallet Prism Black-Red                                    0.00         0
# Miniwallet Prism Stone                                        0.00         0
# Miniwallet Rango Black                                        0.00         0
# Miniwallet Rango Blue-Titanium                                0.00         0
# Miniwallet Rango Brown-Brown                                  0.00         0
# Miniwallet Rango Green                                        0.00         0
# Miniwallet Rango Green-Gold                                   0.00         0
# Miniwallet Rango Red-Bordeaux                                 0.00         0
# Miniwallet Rango Violet-Violet                                0.00         0
# Miniwallet Recycled Natural                                   0.00         0
# Miniwallet Recycled Stone                                     0.00         0
# Miniwallet Stitch Linea Black                                 0.00         0
# Miniwallet Stitch Linea Caramello                             0.00         0
# Miniwallet Stitch Linea Espresso                              0.00         0
# Miniwallet Stitch Linea Navy                                  0.00         0
# Additional Slide Blue                                         0.00         0
# Miniwallet Stitch Magnolia Petrolio                           0.00         0
# Miniwallet Metallic Rose Bordeaux                             0.00         0
# Miniwallet Metallic Moro                                      0.00         0
# Miniwallet Crisple Indigo                                     0.00         0
# Miniwallet Metallic Champagne-Brown                           0.00         0
# Miniwallet Crisple Lemon                                      0.00         0
# Miniwallet Crisple Orange                                     0.00         0
# Miniwallet Crisple Pistachio Floral                           0.00         0
# Miniwallet Crisple Rose Floral                                0.00         0
# Miniwallet Crisple Taupe Camo                                 0.00         0
# Miniwallet Cubic Black                                        0.00         0
# Miniwallet Cubic Black-Blue                                   0.00         0
# Miniwallet Dash Navy                                          0.00         0
# Miniwallet Diamond Black                                      0.00         0
# Miniwallet Glamour Bronze                                     0.00         0
# Miniwallet Glamour Green                                      0.00         0
# Miniwallet Indigo 3                                           0.00         0
# Miniwallet Indigo 5                                           0.00         0
# Miniwallet Matte Black                                        0.00         0
# Miniwallet Matte Black & Red                                  0.00         0
# Miniwallet Matte Black & Yellow                               0.00         0
# Miniwallet Matte Blue                                         0.00         0
# Miniwallet Matte Brick-Black                                  0.00         0
# Miniwallet Matte Chalk                                        0.00         0
# Miniwallet Matte Green                                        0.00         0
# Miniwallet Matte Green-Black                                  0.00         0
# Miniwallet Matte Grey-Black                                   0.00         0
# Miniwallet Matte Lilac-Black                                  0.00         0
# Miniwallet Matte Nightblue                                    0.00         0
# Miniwallet Matte Petrol                                       0.00         0
# Miniwallet Matte Pink                                         0.00         0
# Miniwallet Matte Purple                                       0.00         0
# Twinwallet Vintage Ochre                                      0.00         0

# %%
# netherlands fashionable breakdown
miniwalletfashionabledesign = miniwalletfashionabledesign[(miniwalletfashionabledesign.shipping_country == 'Netherlands')]

# %%
miniwalletfashionabledesign.head()
# Out:
#     internal_id document_number       date  \
# 10      1393213       I-1729849 2018-01-02
# 11      1393213       I-1729849 2018-01-02
# 17      1393213       I-1729849 2018-01-02
# 196     1394925        I-180013 2018-01-02
# 211     1394929        I-180014 2018-01-02
#
#                                customer_name customer_category retailer_role  \
# 10   C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 11   C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 17   C-6355 P.W. Akkerman Vulpenspeciaalzaak        Stationery           NaN
# 196            C-13603 Secrid Webshop België            Intern           NaN
# 211                    C-9866 Secrid Webshop           Webshop           NaN
#
#     shipping_country           item                display_name  quantity  \
# 10       Netherlands      MC-Orange   Miniwallet Crisple Orange         2
# 11       Netherlands       MC-Black    Miniwallet Crisple Black         2
# 17       Netherlands       MN-Black       Miniwallet Nile Black         2
# 196      Netherlands  MPr-Black-Red  Miniwallet Prism Black-Red         1
# 211      Netherlands       MC-Black    Miniwallet Crisple Black         3
#
#      amount  amount_foreign_currency pim_category type_of_material pim_colour  \
# 10    50.38                    50.38   Miniwallet          Crisple     Orange
# 11    50.38                    50.38   Miniwallet          Crisple      Black
# 17    56.38                    56.38   Miniwallet             Nile      Black
# 196   45.41                    45.41   Miniwallet            Prism      Black
# 211  136.23                   136.23   Miniwallet          Crisple      Black
#
#     wsl while_stock_lasts cardprotector_colour design
# 10   No                No               Silver    fsh
# 11   No                No                Black    fsh
# 17   No                No                Black    fsh
# 196  No               Yes                  Red    fsh
# 211  No                No                Black    fsh

# %%
sum(amount for amount in miniwalletfashionabledesign.amount)
# Out:
# 1551885.7299993662

# %%
netherlandsfashionabledesign= miniwalletfashionabledesign.groupby(
   ['display_name']
).agg(
    {
         'amount':sum,    # Sum revenue per customer
         'quantity': sum  # get the sum of items sold per year
         
    }
)

netherlandsfashionabledesign.sort_values(by=['amount'], inplace=True, ascending=False)

# %%
netherlandsfashionabledesign
# Out:
#                                                             amount  quantity
# display_name
# Miniwallet Crisple Black                                 167353.09      6475
# Miniwallet Indigo 5                                      140964.88      4854
# Miniwallet Prism Black-Red                               115006.44      4461
# Miniwallet Cubic Black-Blue                               97806.13      3805
# Miniwallet Crisple Black-Gold                             90340.75      3452
# Miniwallet Metallic Champagne-Brown                       79218.52      3077
# Miniwallet Nile Black                                     63969.51      2237
# Miniwallet Matte Purple                                   59628.49      2552
# Miniwallet Crisple Amber                                  58076.86      2219
# Miniwallet Rango Red-Bordeaux                             47247.33      1842
# Miniwallet Metallic Rose Bordeaux                         45855.68      1763
# Miniwallet Metallic Rose                                  44052.02      1677
# Miniwallet Prism Black                                    41252.99      1606
# Miniwallet Stitch Magnolia Petrolio                       40754.83      1159
# Miniwallet Nile Brown                                     40063.72      1376
# Miniwallet Crisple Orange                                 39723.66      1541
# Miniwallet Ornament Black                                 38507.60      1496
# Miniwallet Stitch Magnolia Rosso                          34414.37       982
# Miniwallet Rango Violet-Violet                            32578.12      1288
# Cardprotector Laser Magnolia Black                            0.00         0
# Cardprotector Laser Magnolia Bordeaux                         0.00         0
# Cardprotector Laser Provence Green                            0.00         0
# Cardprotector Laser Provence Violet                           0.00         0
# Miniwallet Dutch Martin Cacao-Brown                           0.00         0
# Miniwallet Dutch Martin Olive                                 0.00         0
# Miniwallet limited white-black                                0.00         0
# Miniwallet Polished Black (KLM)                               0.00         0
# Miniwallet Rango Black                                        0.00         0
# Miniwallet Rango Blue-Titanium                                0.00         0
# Miniwallet Rango Brown-Brown                                  0.00         0
# Miniwallet Rango Green-Gold                                   0.00         0
# Miniwallet Recycled Natural                                   0.00         0
# Miniwallet Recycled Stone                                     0.00         0
# Additional Slide Blue                                         0.00         0
# Miniwallet Veg Black                                          0.00         0
# Miniwallet Veg Caramello                                      0.00         0
# Miniwallet Veg Espresso                                       0.00         0
# Miniwallet Veg Navy                                           0.00         0
# Miniwallet Veg Rosso                                          0.00         0
# Miniwallet Vegan Soft Touch Black                             0.00         0
# Miniwallet Vintage Black                                      0.00         0
# Miniwallet Vintage Blue                                       0.00         0
# Miniwallet Vintage Brown                                      0.00         0
# Miniwallet Vintage Chocolate                                  0.00         0
# Miniwallet Vintage Cognac                                     0.00         0
# Miniwallet Vintage Cognac-Rust                                0.00         0
# Miniwallet Vintage Concrete                                   0.00         0
# Miniwallet Vintage Grey                                       0.00         0
# Miniwallet Vintage Grey-Black                                 0.00         0
# Miniwallet Vintage Ochre                                      0.00         0
# Miniwallet Vintage Olive-Black                                0.00         0
# Miniwallet Vintage Rose                                       0.00         0
# Miniwallet Polished Navy Exclusive                            0.00         0
# Miniwallet Perforated Cognac                                  0.00         0
# Miniwallet Dutch Martin Whiskey                               0.00         0
# Miniwallet Perforated Black                                   0.00         0
# Miniwallet Glamour Bronze                                     0.00         0
# Miniwallet Glamour Green                                      0.00         0
# Miniwallet Matte Black                                        0.00         0
# Miniwallet Matte Blue                                         0.00         0
# Miniwallet Matte Brick-Black                                  0.00         0
# Miniwallet Matte Chalk                                        0.00         0
# Miniwallet Matte Green                                        0.00         0
# Miniwallet Matte Green-Black                                  0.00         0
# Miniwallet Matte Grey-Black                                   0.00         0
# Miniwallet Matte Lilac-Black                                  0.00         0
# Miniwallet Matte Nightblue                                    0.00         0
# Miniwallet Matte Petrol                                       0.00         0
# Miniwallet Matte Pink                                         0.00         0
# Miniwallet Original Black                                     0.00         0
# Miniwallet Original Black Exclusive                           0.00         0
# Miniwallet Original Black Red Exclusive                       0.00         0
# Miniwallet Original Bordeaux                                  0.00         0
# Miniwallet Original Cognac-Brown                              0.00         0
# Miniwallet Original Dark Brown                                0.00         0
# Miniwallet Original Emerald                                   0.00         0
# Miniwallet Original Fuchsia                                   0.00         0
# Miniwallet Original Green                                     0.00         0
# Miniwallet Original Navy                                      0.00         0
# Miniwallet Original Navy-Blue                                 0.00         0
# Miniwallet Original Red-Red                                   0.00         0
# Twinwallet Vintage Ochre                                      0.00         0
